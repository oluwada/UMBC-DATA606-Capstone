# %% [markdown]
# # Analyzing the Biological Signatures of Vitamin D Deficiency using Cardiac Metrics
# - Goal: To get familiar with the dataset

# %%
# %pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 12.8 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 19.5 MB 27.3 MB/s
# ...
#      |████████████████████████████████| 509 kB 93.3 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('KS5_VDD TRPC6_Complete data set - Complete HRV data.csv')

# %%
df
# Out:
#      Animal ID Diet         SDNN        RMSSD           LF            HF  \
# 0            1  VDD  2.318370611  3.162486522  1.255926881  0.3848496568
# 1            1  VDD  4.389036434   5.68456557  9.937629564   2.608411508
# 2            1  VDD  4.737966399  4.883237771  1.016998621  0.3274906663
# 3            1  VDD   5.85714937  5.958268489  9.576658953  0.9039833695
# 4            1  VDD  3.641280699  4.345562804  1.893925384   0.498826612
# ...        ...  ...          ...          ...          ...           ...
# 1866       18g   ND  4.183793385  6.228482272   1.47598015   1.587951757
# 1867       18g   ND  4.586862068  6.694862251  3.064272078   1.691885379
# 1868       18g   ND   4.50034549  6.600241421  2.005005892   2.092790562
# 1869       18g   ND  4.027999959  6.219095019  4.820783487   3.253889371
# 1870       18g   ND  6.543392008  3.877408417            .             .
#
#              LF/HF         timepoint         dose  \
# ...

# %% [markdown]
# # Understanding the Data

# %%
df.head()
# fist five rows of data
# An unamed column I didn't notice when looking at the spreadsheet
# Out:
#   Animal ID Diet         SDNN        RMSSD           LF            HF  \
# 0         1  VDD  2.318370611  3.162486522  1.255926881  0.3848496568
# 1         1  VDD  4.389036434   5.68456557  9.937629564   2.608411508
# 2         1  VDD  4.737966399  4.883237771  1.016998621  0.3274906663
# 3         1  VDD   5.85714937  5.958268489  9.576658953  0.9039833695
# 4         1  VDD  3.641280699  4.345562804  1.893925384   0.498826612
#
#          LF/HF        timepoint       dose                       Trt Code  \
# 0  3.263422114  dobutamine only  0.5 mg/kg  VDD-dobutamine only-0.5 mg/kg
# 1  3.809839641  dobutamine only  0.5 mg/kg  VDD-dobutamine only-0.5 mg/kg
# 2  3.105427805  dobutamine only  0.5 mg/kg  VDD-dobutamine only-0.5 mg/kg
# 3  10.59384417  dobutamine only  0.5 mg/kg  VDD-dobutamine only-0.5 mg/kg
# 4  3.796760916  dobutamine only  0.5 mg/kg  VDD-dobutamine only-0.5 mg/kg
#
#   Unnamed: 10
# 0           -
# 1           -
# 2           -
# 3           -
# 4           -

# %%
df.shape
# I thought the 1872 rows of data according to google sheets(should double check)
# Out:
# (1871, 11)

# %%
# checking the nulls
df.isnull().sum() / df.shape[0] * 100

# The missing values are hidden because dots were put as placeholders there
# Out:
# Animal ID      0.0
# Diet           0.0
# SDNN           0.0
# RMSSD          0.0
# LF             0.0
# HF             0.0
# LF/HF          0.0
# timepoint      0.0
# dose           0.0
# Trt Code       0.0
# Unnamed: 10    0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1871 entries, 0 to 1870
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Animal ID    1871 non-null   object
#  1   Diet         1871 non-null   object
#  2   SDNN         1871 non-null   object
#  3   RMSSD        1871 non-null   object
#  4   LF           1871 non-null   object
#  5   HF           1871 non-null   object
#  6   LF/HF        1871 non-null   object
#  7   timepoint    1871 non-null   object
#  8   dose         1871 non-null   object
#  9   Trt Code     1871 non-null   object
#  10  Unnamed: 10  1871 non-null   object
# dtypes: object(11)
# memory usage: 160.9+ KB

# %%
df = df.drop(columns = ['Unnamed: 10'])
df
# removed unecessary Unamed Column
# Out:
#      Animal ID Diet         SDNN        RMSSD           LF            HF  \
# 0            1  VDD  2.318370611  3.162486522  1.255926881  0.3848496568
# 1            1  VDD  4.389036434   5.68456557  9.937629564   2.608411508
# 2            1  VDD  4.737966399  4.883237771  1.016998621  0.3274906663
# 3            1  VDD   5.85714937  5.958268489  9.576658953  0.9039833695
# 4            1  VDD  3.641280699  4.345562804  1.893925384   0.498826612
# ...        ...  ...          ...          ...          ...           ...
# 1866       18g   ND  4.183793385  6.228482272   1.47598015   1.587951757
# 1867       18g   ND  4.586862068  6.694862251  3.064272078   1.691885379
# 1868       18g   ND   4.50034549  6.600241421  2.005005892   2.092790562
# 1869       18g   ND  4.027999959  6.219095019  4.820783487   3.253889371
# 1870       18g   ND  6.543392008  3.877408417            .             .
#
#              LF/HF         timepoint         dose  \
# ...

# %%
df = df[['Animal ID','SDNN','RMSSD','LF','HF','LF/HF','timepoint','dose','Trt Code','Diet']]
df
#REordered the dataset so the label/target column woild be at the end.
# Out:
#      Animal ID         SDNN        RMSSD           LF            HF  \
# 0            1  2.318370611  3.162486522  1.255926881  0.3848496568
# 1            1  4.389036434   5.68456557  9.937629564   2.608411508
# 2            1  4.737966399  4.883237771  1.016998621  0.3274906663
# 3            1   5.85714937  5.958268489  9.576658953  0.9039833695
# 4            1  3.641280699  4.345562804  1.893925384   0.498826612
# ...        ...          ...          ...          ...           ...
# 1866       18g  4.183793385  6.228482272   1.47598015   1.587951757
# 1867       18g  4.586862068  6.694862251  3.064272078   1.691885379
# 1868       18g   4.50034549  6.600241421  2.005005892   2.092790562
# 1869       18g  4.027999959  6.219095019  4.820783487   3.253889371
# 1870       18g  6.543392008  3.877408417            .             .
#
#              LF/HF         timepoint         dose  \
# 0      3.263422114   dobutamine only    0.5 mg/kg
# ...
